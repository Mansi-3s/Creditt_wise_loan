# %% [markdown]
# <a href="https://colab.research.google.com/github/Mansi-3s/Creditt_wise_loan/blob/main/Q_Learning_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gymnasium

# %%
import numpy as np
import random
import gymnasium as gym

# %%
gamma = 0.99
alpha = 0.5
epsilon = 0.1 #(explore, exploit)
episodes = 500

# %%
# policy - epsiolon-greedy

def epsilon_greedy(state):
  if random.random() < epsilon:
    return env.action_space.sample() # random action => EXPLORE
  else:
    return np.argmax(Q[state]) # greedy action => EXPLOIT

# %%
Q = np.zeros((48, 4))

# %%
# Q-learning:


# end of episodes two cases 1. terminate(agent reaches end E), 2. truncate(limit, cut-short)

for episode in range(episodes):
  render = (episode % 50 == 0)
  if render:
    env = gym.make("CliffWalking-v1", render_mode="human")
  else:
    env = gym.make("CliffWalking-v1")


  done = False
  state, _ = env.reset()

  total_reward = 0
  episode_len = 0

  while not done:
    action = epsilon_greedy(state)
    nxt_state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated


    # Q-learning update rule
    # Using np.max(Q[nxt_state]) for the Bellman optimality equation target
    Q[state, action] = Q[state, action] + alpha * (reward + gamma * np.max(Q[nxt_state]) - Q[state, action])

    state = nxt_state
    # Removed 'action = nxt_action' as it's incorrect and redundant.
    # The next action will be chosen by epsilon_greedy(state) at the start of the next loop iteration.
    total_reward += reward
    episode_len += 1

  print(f"Episode: {episode + 1}, Total Reward: {total_reward}, Episode Length: {episode_len}")

env.close()
# Out:
# Episode: 1, Total Reward: -124, Episode Length: 25
# Episode: 2, Total Reward: -15, Episode Length: 15
# Episode: 3, Total Reward: -124, Episode Length: 25
# Episode: 4, Total Reward: -13, Episode Length: 13
# Episode: 5, Total Reward: -13, Episode Length: 13
# Episode: 6, Total Reward: -17, Episode Length: 17
# Episode: 7, Total Reward: -13, Episode Length: 13
# Episode: 8, Total Reward: -21, Episode Length: 21
# Episode: 9, Total Reward: -13, Episode Length: 13
# Episode: 10, Total Reward: -15, Episode Length: 15
# Episode: 11, Total Reward: -13, Episode Length: 13
# Episode: 12, Total Reward: -13, Episode Length: 13
# Episode: 13, Total Reward: -17, Episode Length: 17
# Episode: 14, Total Reward: -13, Episode Length: 13
# Episode: 15, Total Reward: -15, Episode Length: 15
# Episode: 16, Total Reward: -15, Episode Length: 15
# Episode: 17, Total Reward: -13, Episode Length: 13
# Episode: 18, Total Reward: -13, Episode Length: 13
# Episode: 19, Total Reward: -15, Episode Length: 15
# ...

# %%
# what did our agent learn?

env = gym.make("CliffWalking-v1", render_mode = "human")
state, _ = env.reset()
total_reward = 0
episode_len = 0
done  = False

while not done:
  action = np.argmax(Q[state])
  state, reward, terminated, truncated, _ = env.step(action)
  done = terminated or truncated

  total_reward += reward
  episode_len += 1


print(f"Total Reward: {total_reward}, Episode Length: {episode_len}")

env.close()
# Out:
# Total Reward: -13, Episode Length: 13

# %%
Q[36] # Q(s, a) state = 36
# [ 0 = -12.2478977, 1 = -112.12..., 2 = -13.12..., 3 = -13.1254....] 0 = UP, 1= RIGHT, 2 = Move DOWN, 3 = LEFT
# These are rewards : 0 has maximum reward mean we have to move UP.
# Out:
# array([ -12.2478977 , -112.12541872,  -13.12541872,  -13.12541872])

# %%
Q[35]
# Out:
# array([-2.97009605, -1.99      , -1.        , -2.97009992])
